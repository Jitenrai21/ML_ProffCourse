# %%
import os
import zipfile

# %%
# !pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/82.7 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/82.7 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/82.7 kB 262.6 kB/s eta 0:00:01
#      ------------------ ------------------- 41.0/82.7 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 82.7/82.7 kB 387.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/78.2 kB ? eta -:--:--
#    -------------------- ------------------- 41.0/78.2 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 78.2/78.2 kB 722.5 kB/s eta 0:00:00
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105797 sha256=e06db52416a0ae0732279c2c9915f5faf0ac7c650d1c0c943af45a04cfc600e7
# ...

# %%
kaggle_path = os.path.expanduser('~/.kaggle')
os.makedirs(kaggle_path, exist_ok=True)

# %%
import shutil
shutil.copy('kaggle.json', os.path.join(kaggle_path, 'kaggle.json'))
# Out:
# 'C:\\Users\\ACER/.kaggle\\kaggle.json'

# %%
os.chmod(os.path.join(kaggle_path, 'kaggle.json'), 0o600)

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Dataset URL: https://www.kaggle.com/datasets/salader/dogs-vs-cats
# License(s): unknown
# ...
#   0%|          | 0.00/1.06G [00:00<?, ?B/s]
#   0%|          | 1.00M/1.06G [00:01<28:23, 670kB/s]
#   0%|          | 2.00M/1.06G [00:01<14:05, 1.35MB/s]
#   0%|          | 3.00M/1.06G [00:01<08:46, 2.17MB/s]
#   0%|          | 5.00M/1.06G [00:02<04:38, 4.08MB/s]
#   1%|          | 7.00M/1.06G [00:02<03:00, 6.28MB/s]
#   1%|          | 9.00M/1.06G [00:02<02:17, 8.26MB/s]
#   1%|1         | 11.0M/1.06G [00:02<01:48, 10.4MB/s]
#   1%|1         | 13.0M/1.06G [00:02<01:36, 11.7MB/s]
#   1%|1         | 16.0M/1.06G [00:02<01:23, 13.4MB/s]
#   2%|1         | 18.0M/1.06G [00:02<01:15, 14.9MB/s]
#   2%|1         | 20.0M/1.06G [00:02<01:13, 15.2MB/s]
#   2%|2         | 22.0M/1.06G [00:03<01:23, 13.4MB/s]
#   2%|2         | 25.0M/1.06G [00:03<01:05, 17.1MB/s]
#   2%|2         | 27.0M/1.06G [00:03<01:10, 15.7MB/s]
#   3%|2         | 29.0M/1.06G [00:03<01:10, 15.7MB/s]
# ...

# %%
zip_file_path = 'dogs-vs-cats.zip'
extract_path = r'C:\Users\ACER\OneDrive\Desktop\ML_ProffCourse\Day-09'
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print(f'Dataset extracted to: {extract_path}')
# Out:
# Dataset extracted to: C:\Users\ACER\OneDrive\Desktop\ML_ProffCourse\Day-09
